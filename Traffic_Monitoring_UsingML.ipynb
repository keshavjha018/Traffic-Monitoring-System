# %%
# Call Algorithm - YOLOv5
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5

# Install Dependencies
# %pip install -qr requirements.txt  # install


import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-160-g867f7f0 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %% [markdown]
# #**Training On Custom Vehicles DataSet**

# %%
# Unzip Custom Training Dataset
from google.colab import drive
drive.mount('/content/drive')

# !unzip -q /content/drive/MyDrive/traffic_data.zip -d ../
# Out:
# Mounted at /content/drive

# %%
#@title Selecting logger {run: 'auto'}
logger = 'TensorBoard' #@param ['ClearML', 'Comet', 'TensorBoard']

# Default: Tensorboard. Directory: runs/train

if logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train

# %%
# Train YOLOv5s on TrafficDataset
# !python train.py --img 640 --batch 16 --epochs 60 --data custom_training.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_training.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-160-g867f7f0 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# Too many epochs will lead to overfitting of data, meaning it will learn to fit the training data too well, leading to poor generalization performance on new, unseen data.

# %%
# Download Weight file & Training Details

# Navigate to that FOLDER
# %cd /content/yolov5/runs/train/exp

# Create Zip
# !zip -r train.zip .
# Out:
# /content/yolov5/runs/train/exp
#   adding: labels_correlogram.jpg (deflated 27%)
#   adding: val_batch1_labels.jpg (deflated 7%)
#   adding: weights/ (stored 0%)
#   adding: weights/last.pt (deflated 9%)
#   adding: weights/best.pt (deflated 9%)
#   adding: events.out.tfevents.1682974661.52ffeae4e757.1487.0 (deflated 17%)
#   adding: val_batch2_labels.jpg (deflated 7%)
#   adding: results.csv (deflated 83%)
#   adding: PR_curve.png (deflated 6%)
#   adding: val_batch0_pred.jpg (deflated 6%)
#   adding: F1_curve.png (deflated 4%)
#   adding: hyp.yaml (deflated 45%)
#   adding: train_batch2.jpg (deflated 5%)
#   adding: val_batch0_labels.jpg (deflated 6%)
#   adding: val_batch2_pred.jpg (deflated 7%)
#   adding: val_batch1_pred.jpg (deflated 7%)
#   adding: train_batch1.jpg (deflated 5%)
#   adding: R_curve.png (deflated 4%)
#   adding: P_curve.png (deflated 3%)
#   adding: train_batch0.jpg (deflated 4%)
#   adding: opt.yaml (deflated 49%)
#   adding: results.png (deflated 10%)
# ...

# %%
# Download
from google.colab import files
files.download("train.zip")

# %% [markdown]
# #Detect

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)

# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/traffic-img.jpg
